# %% [markdown]
# Time Series
#
# 시게열 데이터 분석
# - 주기성 (Periodicity) , 추세 (Trend) , 계절성 (Seasonal)존재

# %% [markdown]
# # LSTM - Time Serise Dataset
#
# * 서울시 기후 데이터 : 2011년 01월 01일 ~ 2019년 12월 31일
# * https://data.kma.go.kr/cmmn/main.do
# * 기후통계분석 -> 기온분석 -> 기간(20110101~20191231) -> 검색 -> CSV 다운로드
# * Seoul_Temp.csv

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Import Packages
#
# * Packages

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %% [markdown]
# # I. Colab File Upload

# %% [markdown]
# > ## 1) 'Seoul_Temp.csv' 파일을 Colab에 업로드 후 진행

# %%
url = 'https://raw.githubusercontent.com/rusita-ai/pyData/master/Seoul_Temp.csv'
temp = pd.read_csv(url)

temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3287 entries, 0 to 3286
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    3287 non-null   object
#  1   avg     3287 non-null   float64
#  2   min     3287 non-null   float64
#  3   max     3287 non-null   float64
# dtypes: float64(3), object(1)
# memory usage: 102.8+ KB

# %%
temp.head()
# Out:
#          date  avg   min  max
# 0  2011-01-01 -6.8 -10.4 -2.9
# 1  2011-01-02 -5.4  -8.5 -1.2
# 2  2011-01-03 -4.5  -8.5 -0.3
# 3  2011-01-04 -3.9  -7.4 -1.7
# 4  2011-01-05 -4.0  -7.7 -1.8

# %% [markdown]
# # II. Data Preprocessing

# %% [markdown]
# > ## 1) 일일 평균온도('avg') 변화 시각화
#
# * 일일 평균온도 변화에 일정한 패턴 확인

# %%
temp_data = temp[['avg']]

plt.figure(figsize = (12, 5))
plt.plot(temp_data)
plt.show()

# %% [markdown]
# > ## 2) Normalization
#
# * tanh Activation 적용을 위해 -1 ~ 1 범위로 정규화

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range = (-1, 1))

temp_data = scaler.fit_transform(temp_data)

# %% [markdown]
# > ## 3) Train vs. Test Split
#
# * Train_Dataset : 2011년 01월 01일 ~ 2017년 12월 31일
# * Test_Dataset : 2018년 01월 01일 ~ 2019년 12월 31일

# %%
train = temp_data[0:2557]
test  = temp_data[2557:]

# %% [markdown]
# # III. 시계열 데이터 처리 함수

# %% [markdown]
# 시계열데이터는 train,test split할때 랜덤하게 추출하면 안되고, <br>
# 시간순서에 따라 훈련데이터를 분리해 줘야함 <br>
#
# self_supervised data : 데이터에 x 데이터와 y데이터가 함께 들어가있음 <br>
# x데이터 : 180간의 평균온도  <br>
# y데이터 : 181일의 평균온도  <br>

# %% [markdown]
# > ## 1) 시계열 학습용 데이터 생성 함수 정의
#
# * X : 학습 평균온도 데이터
# * y : 정답 평균온도 데이터
# * 일정 기간의 X로 y를 예측하도록 학습

# %%
def create_dataset(time_data, look_back = 1):
    data_X, data_y = [], []

    for i in range(len(time_data) - look_back):
        data_X.append(time_data[i:(i + look_back), 0]) #i= 0 , data_x = 0~149번 데이터
        data_y.append(time_data[i + look_back, 0]) #i= 0, data_y = 150번째 데이터

    return np.array(data_X), np.array(data_y)

# %% [markdown]
# > ## 2) loop_back 기간 설정 후 학습데이터 생성
#
# * 180일 기간 평균온도로 다음날 평균온도 예측 데이터 생성

# %%
look_back = 180

train_X, train_y = create_dataset(train, look_back)
test_X,  test_y  = create_dataset(test, look_back)

train_X.shape, train_y.shape, test_X.shape, test_y.shape
# Out:
# ((2377, 180), (2377,), (550, 180), (550,))

# %% [markdown]
# > ## 3) Tensor Reshape

# %%
train_X = np.reshape(train_X, (train_X.shape[0], train_X.shape[1], 1)) #2377차원, 1차원당 180행, 1열의 텐서로 만듬
test_X = np.reshape(test_X, (test_X.shape[0], test_X.shape[1], 1))

train_X.shape, train_y.shape, test_X.shape, test_y.shape
# Out:
# ((2377, 180, 1), (2377,), (550, 180, 1), (550,))

# %% [markdown]
# # IV. LSTM Modeling

# %% [markdown]
# > ## 1) Model Define

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM

model = Sequential(name = 'LSTM')
model.add(LSTM(128, 
               input_shape = (None, 1))) #(180,1)
model.add(Dense(1, activation = 'tanh'))

# %% [markdown]
# * Model Summary

# %%
model.summary()
# Out:
# Model: "LSTM"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 128)               66560
#
#  dense (Dense)               (None, 1)                 129
#
# =================================================================
# Total params: 66,689
# Trainable params: 66,689
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# > ## 2) Model Compile

# %%
model.compile(loss = 'mse',
              optimizer = 'rmsprop',
              metrics = ['mae'])

# %% [markdown]
# > ## 3) Model Fit
#
# * 약 7분

# %%
# %%time

hist = model.fit(train_X, train_y,
                 epochs = 200, 
                 batch_size = 16,  
                 validation_data = (test_X, test_y))
# Out:
# Epoch 1/200
# 149/149 [==============================] - 10s 17ms/step - loss: 0.0203 - mae: 0.1075 - val_loss: 0.0137 - val_mae: 0.0904
# Epoch 2/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0138 - mae: 0.0902 - val_loss: 0.0112 - val_mae: 0.0813
# Epoch 3/200
# 149/149 [==============================] - 1s 9ms/step - loss: 0.0124 - mae: 0.0848 - val_loss: 0.0107 - val_mae: 0.0801
# Epoch 4/200
# 149/149 [==============================] - 1s 9ms/step - loss: 0.0111 - mae: 0.0804 - val_loss: 0.0100 - val_mae: 0.0779
# Epoch 5/200
# 149/149 [==============================] - 1s 9ms/step - loss: 0.0104 - mae: 0.0777 - val_loss: 0.0094 - val_mae: 0.0742
# Epoch 6/200
# 149/149 [==============================] - 1s 9ms/step - loss: 0.0098 - mae: 0.0753 - val_loss: 0.0113 - val_mae: 0.0832
# Epoch 7/200
# 149/149 [==============================] - 1s 9ms/step - loss: 0.0094 - mae: 0.0739 - val_loss: 0.0087 - val_mae: 0.0694
# Epoch 8/200
# 149/149 [==============================] - 1s 9ms/step - loss: 0.0092 - mae: 0.0720 - val_loss: 0.0083 - val_mae: 0.0691
# Epoch 9/200
# 149/149 [==============================] - 2s 10ms/step - loss: 0.0079 - mae: 0.0662 - val_loss: 0.0075 - val_mae: 0.0662
# Epoch 110/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0079 - mae: 0.0666 - val_loss: 0.0076 - val_mae: 0.0678
# Epoch 111/200
# 149/149 [==============================] - 1s 9ms/step - loss: 0.0079 - mae: 0.0667 - val_loss: 0.0073 - val_mae: 0.0651
# Epoch 112/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0079 - mae: 0.0664 - val_loss: 0.0073 - val_mae: 0.0651
# Epoch 113/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0079 - mae: 0.0667 - val_loss: 0.0077 - val_mae: 0.0658
# Epoch 114/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0079 - mae: 0.0664 - val_loss: 0.0075 - val_mae: 0.0666
# Epoch 115/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0079 - mae: 0.0664 - val_loss: 0.0076 - val_mae: 0.0667
# Epoch 116/200
# 149/149 [==============================] - 2s 13ms/step - loss: 0.0079 - mae: 0.0665 - val_loss: 0.0076 - val_mae: 0.0669
# Epoch 117/200
# 149/149 [==============================] - 2s 11ms/step - loss: 0.0079 - mae: 0.0666 - val_loss: 0.0073 - val_mae: 0.0654
# Epoch 118/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0079 - mae: 0.0664 - val_loss: 0.0075 - val_mae: 0.0653
# Epoch 119/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0079 - mae: 0.0666 - val_loss: 0.0075 - val_mae: 0.0666
# Epoch 120/200
# 149/149 [==============================] - 1s 9ms/step - loss: 0.0079 - mae: 0.0665 - val_loss: 0.0075 - val_mae: 0.0663
# Epoch 121/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0079 - mae: 0.0666 - val_loss: 0.0076 - val_mae: 0.0675
# Epoch 122/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0079 - mae: 0.0664 - val_loss: 0.0074 - val_mae: 0.0663
# Epoch 123/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0079 - mae: 0.0665 - val_loss: 0.0074 - val_mae: 0.0653
# Epoch 124/200
# 149/149 [==============================] - 2s 12ms/step - loss: 0.0078 - mae: 0.0662 - val_loss: 0.0085 - val_mae: 0.0716
# Epoch 125/200
# 149/149 [==============================] - 2s 11ms/step - loss: 0.0079 - mae: 0.0663 - val_loss: 0.0073 - val_mae: 0.0650
# Epoch 126/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0078 - mae: 0.0664 - val_loss: 0.0074 - val_mae: 0.0653
# Epoch 127/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0079 - mae: 0.0663 - val_loss: 0.0076 - val_mae: 0.0674
# Epoch 128/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0079 - mae: 0.0664 - val_loss: 0.0073 - val_mae: 0.0649
# Epoch 129/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0078 - mae: 0.0660 - val_loss: 0.0074 - val_mae: 0.0662
# Epoch 170/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0078 - mae: 0.0663 - val_loss: 0.0073 - val_mae: 0.0650
# Epoch 171/200
# 149/149 [==============================] - 2s 12ms/step - loss: 0.0078 - mae: 0.0659 - val_loss: 0.0075 - val_mae: 0.0670
# Epoch 172/200
# 149/149 [==============================] - 2s 12ms/step - loss: 0.0078 - mae: 0.0662 - val_loss: 0.0074 - val_mae: 0.0649
# Epoch 173/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0078 - mae: 0.0658 - val_loss: 0.0082 - val_mae: 0.0699
# Epoch 174/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0078 - mae: 0.0660 - val_loss: 0.0073 - val_mae: 0.0652
# Epoch 175/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0078 - mae: 0.0661 - val_loss: 0.0073 - val_mae: 0.0656
# Epoch 176/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0077 - mae: 0.0657 - val_loss: 0.0074 - val_mae: 0.0663
# Epoch 177/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0078 - mae: 0.0659 - val_loss: 0.0075 - val_mae: 0.0651
# Epoch 178/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0078 - mae: 0.0660 - val_loss: 0.0073 - val_mae: 0.0661
# Epoch 179/200
# 149/149 [==============================] - 2s 12ms/step - loss: 0.0078 - mae: 0.0657 - val_loss: 0.0074 - val_mae: 0.0664
# Epoch 180/200
# 149/149 [==============================] - 2s 11ms/step - loss: 0.0078 - mae: 0.0662 - val_loss: 0.0072 - val_mae: 0.0646
# Epoch 181/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0078 - mae: 0.0658 - val_loss: 0.0073 - val_mae: 0.0641
# Epoch 182/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0078 - mae: 0.0659 - val_loss: 0.0076 - val_mae: 0.0670
# Epoch 183/200
# 149/149 [==============================] - 1s 9ms/step - loss: 0.0078 - mae: 0.0657 - val_loss: 0.0074 - val_mae: 0.0659
# Epoch 184/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0077 - mae: 0.0660 - val_loss: 0.0075 - val_mae: 0.0650
# Epoch 185/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0078 - mae: 0.0659 - val_loss: 0.0073 - val_mae: 0.0650
# Epoch 186/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0078 - mae: 0.0660 - val_loss: 0.0077 - val_mae: 0.0673
# Epoch 187/200
# 149/149 [==============================] - 2s 12ms/step - loss: 0.0077 - mae: 0.0656 - val_loss: 0.0078 - val_mae: 0.0676
# Epoch 188/200
# 149/149 [==============================] - 2s 12ms/step - loss: 0.0077 - mae: 0.0658 - val_loss: 0.0074 - val_mae: 0.0653
# Epoch 189/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0078 - mae: 0.0661 - val_loss: 0.0073 - val_mae: 0.0653
# Epoch 190/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0077 - mae: 0.0659 - val_loss: 0.0073 - val_mae: 0.0646
# Epoch 191/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0077 - mae: 0.0660 - val_loss: 0.0073 - val_mae: 0.0650
# Epoch 192/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0077 - mae: 0.0660 - val_loss: 0.0072 - val_mae: 0.0651
# Epoch 193/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0077 - mae: 0.0656 - val_loss: 0.0074 - val_mae: 0.0652
# Epoch 194/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0077 - mae: 0.0659 - val_loss: 0.0074 - val_mae: 0.0669
# Epoch 195/200
# 149/149 [==============================] - 2s 12ms/step - loss: 0.0078 - mae: 0.0659 - val_loss: 0.0075 - val_mae: 0.0652
# Epoch 196/200
# 149/149 [==============================] - 2s 12ms/step - loss: 0.0077 - mae: 0.0653 - val_loss: 0.0074 - val_mae: 0.0661
# Epoch 197/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0077 - mae: 0.0660 - val_loss: 0.0079 - val_mae: 0.0688
# Epoch 198/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0077 - mae: 0.0660 - val_loss: 0.0074 - val_mae: 0.0654
# Epoch 199/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0078 - mae: 0.0658 - val_loss: 0.0073 - val_mae: 0.0658
# Epoch 200/200
# 149/149 [==============================] - 1s 10ms/step - loss: 0.0078 - mae: 0.0658 - val_loss: 0.0075 - val_mae: 0.0666
# CPU times: user 5min 15s, sys: 16 s, total: 5min 31s
# Wall time: 5min 23s

# %% [markdown]
# > ## 4) 학습결과 시각화

# %%
plt.figure(figsize = (12, 5))
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])

plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['Train Loss', 'Valid Loss'], loc = 'upper right')
plt.show()

# %% [markdown]
# > ## 5) Model Evaluate

# %%
trainScore = model.evaluate(train_X, train_y, verbose = 0)
print('Train Score: ', trainScore)

testScore = model.evaluate(test_X, test_y, verbose = 0)
print('Test Score: ', testScore)
# Out:
# Train Score:  [0.007531572598963976, 0.06552068144083023]
# Test Score:  [0.007487989030778408, 0.06656529009342194]

# %% [markdown]
# # V. Model Predict

# %%
look_ahead = 550

xhat = test_X[0]

predictions = np.zeros((look_ahead, 1))

for i in range(look_ahead):
    prediction = model.predict(np.array([xhat]), batch_size = 1, verbose = 0)
    predictions[i] = prediction
    xhat = np.vstack([xhat[1:], prediction])
    
plt.figure(figsize = (12, 5))
plt.plot(np.arange(look_ahead), predictions, 'r', label = 'Prediction')
plt.plot(np.arange(look_ahead), test_y[:look_ahead], label = 'Test_Data')
plt.legend()
plt.show()

# %% [markdown]
# #
# #
# #
# # The End
# #
# #
# #
